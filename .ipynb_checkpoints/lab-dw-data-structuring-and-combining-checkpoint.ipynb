# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here

import pandas as pd
import numpy as np

file1 = pd.read_csv('file1_cleaned.csv', sep = ';')
file2 = pd.read_csv('file2_cleaned.csv', sep = ';')
file3 = pd.read_csv('file3_cleaned.csv', sep = ',')
file1.head()
file1.shape
#We may want to filter by month, for example, or by quarter, or group by month, or sum all Januaries in a decade. All of these are easier to do if the months are in a column than accross multiple
# Out:
# (1071, 11)

# %%
file2.head()
file2.shape
# Out:
# (996, 11)

# %%
file3.head()
file3.shape
# Out:
# (7070, 11)

# %%
file = pd.concat([file1,file2,file3], axis=0, ignore_index=True)
file.tail(25)
# Out:
#      customer       state gender             education  \
# 9112  JR41742  California      M               College
# 9113  RA89822  California      F  High School or Below
# 9114  IJ25462  California      M              Bachelor
# 9115  ZP86347  California      F               College
# 9116  HO82823  California      F              Bachelor
# 9117  EA54906  California      F  High School or Below
# 9118  BC64697  California      F               College
# 9119  VV68726  California      F  High School or Below
# 9120  QR91631  California      F  High School or Below
# 9121  OT56964  California      M                Master
# 9122  YX35990  California      M                Master
# 9123  RN61682  California      F              Bachelor
# 9124  BB10681  California      F               College
# 9125  FH43628  California      F               College
# 9126  WZ45103  California      F              Bachelor
# 9127  CB59349  California      M                Master
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
marketing = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')

marketing.tail(30)
marketing1 = marketing.drop(columns='unnamed:_0')
marketing1.tail(30)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 10880  JG12505      Nevada              4064.182317       No     Basic
# 10881  NL59519  California             11565.687470       No  Extended
# 10882  XW90265     Arizona              5773.520711       No     Basic
# 10883  FD64348      Oregon             22563.618380       No     Basic
# 10884  NP33989      Oregon             12362.087660       No   Premium
# 10885  XM87301      Oregon              2397.536652       No     Basic
# 10886  OS84395      Nevada              7611.949286       No  Extended
# 10887  BY78730      Oregon              8879.790017      Yes     Basic
# 10888  MN95006  California              6928.601611       No     Basic
# 10889  RT36566  California              5260.623466       No     Basic
# 10890  VQ78876      Oregon              4660.399573       No     Basic
# 10891  UV43859      Oregon              8840.193762       No     Basic
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
marketing1.tail(10)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 10900  VN73653      Oregon              6423.739052       No     Basic
# 10901  RY92254  Washington              4547.892543       No   Premium
# 10902  PP30874  California              3579.023825       No  Extended
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#                   education effective_to_date employmentstatus gender  income  \
# 10900               College        2011-02-13       Unemployed      M       0
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
mkt=np.round(pd.pivot_table(marketing1,index='sales_channel',values='customer_lifetime_value', aggfunc=[sum]),2)
display(mkt)
# Out:
#                                   sum
#               customer_lifetime_value
# sales_channel
# Agent                     33057887.85
# Branch                    24359201.21
# Call Center               17364288.37
# Web                       12697632.90

# %%
# It seems that the Agent channel is the one that brought the best customers, it makes sense in a way since the Agent has a more personalized approach to the sale.
# Branch ranks second, which I guess its the customer reaching to the insurance company, Call center and web are the bottom channels, that rely in virtual interaction with the customer.
# the lifetime value could be affected by the number of months the customer has been a client, and it can be inferred, that call center and web are the newest channels, so thats why their lifetime value is lower.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
mkt2=np.round(pd.pivot_table(marketing1,index=['gender','education'],values='customer_lifetime_value', aggfunc=['mean']),2)
display(mkt2)
# Out:
#                                                mean
#                             customer_lifetime_value
# gender education
# F      Bachelor                             7874.27
#        College                              7748.82
#        Doctor                               7328.51
#        High School or Below                 8675.22
#        Master                               8157.05
# M      Bachelor                             7703.60
#        College                              8052.46
#        Doctor                               7415.33
#        High School or Below                 8149.69
#        Master                               8168.83

# %%
# For both genders, the customer that have a Doctors degree, have the less revenue.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
